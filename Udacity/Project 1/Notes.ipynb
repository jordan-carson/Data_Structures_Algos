# %%
calls_f = 'calls.csv'
texts_f = 'texts.csv'

# %%
import pandas as pd

# %%
calls_df = pd.read_csv(calls_f, names=['phone1','phone2', 'time', 'duration'])

# %%
texts_df = pd.read_csv(texts_f)

# %%
texts_df.head()
# Out:
#    97424 22395  90365 06212  01-09-2016 06:03:22
# 0  94489 72078  92415 91418  01-09-2016 06:05:35
# 1  81520 43406  92421 64236  01-09-2016 06:09:34
# 2  97389 12538  90352 50054  01-09-2016 06:09:39
# 3  81515 42171  98440 02823  01-09-2016 06:13:30
# 4  78132 18081  77956 90632  01-09-2016 06:19:37

# %%
import csv
with open('texts.csv', 'r') as f:
    reader = csv.reader(f)
    texts = list(reader)

with open('calls.csv', 'r') as f:
    reader = csv.reader(f)
    calls = list(reader)

# %%
for i in calls[10]:
    print(i)
# Out:
# (04344)228249
# (080)43901222
# 01-09-2016 06:50:04
# 2329

# %%
print("First record of texts, {0} texts {1} at time {2}.".format(*texts[0]))
print("Last record of calls, {0} calls {1} at time {2}, lasting {3} seconds.".format(*calls[-1]))
# Out:
# First record of texts, 97424 22395 texts 90365 06212 at time 01-09-2016 06:03:22.
# Last record of calls, 98447 62998 calls (080)46304537 at time 30-09-2016 23:57:15, lasting 2151 seconds.

# %% [markdown]
# ## TASK 1:
# How many different telephone numbers are there in the records?
# Print a message:
# > **"There are <count> different telephone numbers in the records."**

# %%
unique = set()
for text in texts:
    unique.add(text[0])
    unique.add(text[1])

for call in calls:
    unique.add(call[0])
    unique.add(call[1])

print(len(unique))
# Out:
# 570

# %% [markdown]
# ## TASK 2:
# Which telephone number spent the longest time on the phone
# during the period? Don't forget that time spent answering a call is
# also time spent on the phone.
# Print a message:
#
# > **"(telephone number) spent the longest time, (total time) seconds, on the phone during
# September 2016.".**

# %%
longest = 0
time_d = dict()
phone_temp = ""

for call in calls:
    if call[0] in time_d:
        time_d[call[0]] += int(call[3])
    else:
        time_d[call[0]] = int(call[3])
    
    if call[1] in time_d:
        time_d[call[1]] += int(call[3])
    else:
        time_d[call[1]] = int(call[3])

# %%
from collections import OrderedDict
final = OrderedDict({k: v for k, v in sorted(time_d.items(), key=lambda item: item[1])})
list(final.popitem())
# Out:
# ['(080)33251027', 90456]

# %%
final = sorted(time_d, key=time_d.get, reverse=True)[0]
print('{0} spent the longest time, {1} seconds, on the phone during September 2016'.format(final, time_d[final]))
# Out:
# (080)33251027 spent the longest time, 90456 seconds, on the phone during September 2016

# %%
final_test = max(time_d, key=lambda x: time_d[x])
# final_test
print('{0} spent the longest time, {1} seconds, on the phone during September 2016'.format(final_test, time_d[final_test]))
# Out:
# (080)33251027 spent the longest time, 90456 seconds, on the phone during September 2016

# %%
for text in texts[:1]:
    print(text)
# Out:
# ['97424 22395', '90365 06212', '01-09-2016 06:03:22']

# %%
import sys

# %%
if '3.7' in sys.version: 
    final = OrderedDict({k: v for k, v in sorted(time_d.items(), key=lambda item: item[1])})
    final_items = list(final.popitem())
    print(f"{final_items[0]} spent the longest time, {final_items[1]} seconds, on the phone during September 2016.")
else:
    final = max(time_d, key=lambda x: time_d[x])
    print('{0} spent the longest time, {1} seconds, on the phone during September 2016'.format(final, time_d[final]))
# Out:
# (080)33251027 spent the longest time, 90456 seconds, on the phone during September 2016.

# %% [markdown]
# ## TASK 3:
# (080) is the area code for fixed line telephones in Bangalore.
# Fixed line numbers include parentheses, so Bangalore numbers
# have the form (080)xxxxxxx.)
#
# ### Part A:
# Find all of the area codes and mobile prefixes called by people
# in Bangalore.
#  - Fixed lines start with an area code enclosed in brackets. The area
#    codes vary in length but always begin with 0.
#  - Mobile numbers have no parentheses, but have a space in the middle
#    of the number to help readability. The prefix of a mobile number
#    is its first four digits, and they always start with 7, 8 or 9.
#  - Telemarketers' numbers have no parentheses or space, but they start
#    with the area code 140.
#
# Print the answer as part of a message:
# "The numbers called by people in Bangalore have codes:"
#  <list of codes>
# The list of codes should be print out one per line in lexicographic order with no duplicates.
#
# ### Part B:
# What percentage of calls from fixed lines in Bangalore are made
# to fixed lines also in Bangalore? In other words, of all the calls made
# from a number starting with "(080)", what percentage of these calls
# were made to a number also starting with "(080)"?
#
# Print the answer as a part of a message::
# "<percentage> percent of calls from fixed lines in Bangalore are calls
# to other fixed lines in Bangalore."
# The percentage should have 2 decimal digits

# %%
for i in calls:
    if i[0].startswith('(080'):
        print(i[0])
# Out:
# (080)45291968
# (080)62164823
# (080)67362492
# (080)69245029
# (080)47459867
# (080)23802940
# (080)46304537
# (080)67362492
# (080)32255824
# (080)35986130
# (080)30270642
# (080)29435303
# (080)34121098
# (080)22816760
# (080)46772413
# (080)62164823
# (080)64765396
# (080)35121497
# (080)43685310
# (080)43215621
# (080)23802940
# (080)45547058
# (080)64765396
# (080)23802940
# (080)34932254
# (080)60068611
# (080)68104927
# (080)43685310
# (080)43562014
# (080)46566171
# (080)20227149
# (080)60068611
# (080)45687418
# (080)65275591
# (080)32390650
# (080)44050207
# (080)69245029
# (080)43215621
# (080)46772413
# (080)47999451
# (080)22816760
# (080)20123809
# (080)60062475
# (080)62164823
# (080)30270642
# (080)26097534
# (080)21652896
# (080)43206415
# (080)43562014
# (080)23802940
# (080)22759842
# (080)62164823
# (080)68104927
# (080)47459867
# (080)46702492
# (080)21129907
# (080)46772413
# (080)62164823
# (080)48462898
# (080)62164823
# (080)35986130
# (080)43685310
# ...

# %%
# %alias_magic t timeit
# %t list(filter(lambda x: x[0][:5] == '(080)', calls)) #897 µs ± 40.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %t [i for i in calls if i[0].startswith('(080)')] # 658 µs ± 19.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# Out:
# 658 µs ± 19.3 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
import re

area_codes = dict()
bangalore = list(filter(lambda x: x[0][:5] == '(080)', calls)) #[i for i in calls if i[0].startswith('(080)')]

for call in bangalore:
    # Fixed 
    if call[1][0] == '(':
        if re.match(r"\(([0-9]+)\)", call[1]).group(0)[1:-1] in area_codes:
            area_codes[re.match(r"\(([0-9]+)\)", call[1]).group(0)[1:-1]] += 1
        else:
            area_codes[re.match(r"\(([0-9]+)\)", call[1]).group(0)[1:-1]] = 1 
#     # Mobile Numbers startwith 7,8,9
#     elif call[1][0].startswith(('7', '8', '9')) :
#         if call[1].split(' ')[0][1:-1] in area_codes:
#             area_codes[call[1].split(' ')[0][1:-1] ]+= 1
#         else:
#             area_codes[call[1].split(' ')[0][1:-1]] = 1
    # Telemarketers
    elif call[1][:3] == '140':
        if '140' in area_codes:
            area_codes['140'] += 1
        else:
            area_codes['140'] = 1
    else:
        # Mobile
        if call[1][:4] in area_codes:
            area_codes[call[1][:4]] += 1
        else:
            area_codes[call[1][:4]] = 1
#     else:
#         if call[1].split(' ')[0][1:-1] in area_codes:
#             area_codes[call[1].split(' ')[0][1:-1]] += 1
#         else:
#             area_codes[call[1].split(' ')[0][1:-1]] = 1
print()
print('Part A:')
print("The numbers called by people in Bangalore have codes:")
for code in sorted(area_codes):
    print(code)

fixedlines = area_codes['080']
alllines = len(bangalore)

print()
print('Part B:')
print(f'{round(fixedlines/alllines*100, 2)}% of calls from fixed lines in Bangalore are calls to other fixed lines in Bangalore.")')
# for exchange in bangalore:
#     re.match(r"\(([0-9]+)\)", exchange[1]).group(0)[1:-1]
# Out:
# Part A:
# The numbers called by people in Bangalore have codes:
# 022
# 040
# 04344
# 044
# 04546
# 0471
# 080
# 0821
# 7406
# 7795
# 7813
# 7829
# 8151
# 8152
# 8301
# 8431
# 8714
# 9008
# 9019
# 9035
# 9036
# 9241
# 9242
# 9341
# 9342
# 9343
# 9400
# 9448
# 9449
# 9526
# 9656
# 9738
# 9740
# 9741
# 9742
# 9844
# 9845
# 9900
# 9961
#
# Part B:
# 24.81% of calls from fixed lines in Bangalore are calls to other fixed lines in Bangalore.")

# %%
[i for i in bangalore if i[1].startswith('140') or i[1].startswith('(140)')]
# Out:
# []

# %%
calls[0][1][:3]
# Out:
# '984'

# %%
calls[0][1].split(' ')[0]
# Out:
# '98453'

# %%
re.match(r"\(([0-9]+)\)", calls[1][0]).group(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-15a0e34b6f56> in <module>
# ----> 1 re.match(r"\(([0-9]+)\)", calls[1][0]).group(0)
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
bangaloreExchanges = list(filter(lambda x: x[0][:5] == '(080)', calls))
codes = {}
print(type(bangaloreExchanges))
from functools import reduce
for exchange in bangaloreExchanges:
    #Fixed Lines
    if exchange[1][0] == '(':
        if re.match(r"\(([0-9]+)\)", exchange[1]).group(0)[1:-1] in codes:
            codes[re.match(r"\(([0-9]+)\)", exchange[1]).group(0)[1:-1]] += 1
        else:
            codes[re.match(r"\(([0-9]+)\)", exchange[1]).group(0)[1:-1]] = 1 
    #Telemarketers 
    elif exchange[1][:3] == '140':
        if '140' in codes:
            codes['140'] += 1
        else:
            codes['140'] = 1
    #Mobile Numbers
    else:
        if exchange[1][:4] in codes:
            codes[exchange[1][:4]] += 1
        else:
            codes[exchange[1][:4]] = 1

print("The numbers called by people in Bangalore have codes:")
for code in sorted([*codes]):
    print(code)
fixedLines = codes['080']
allLines = reduce(lambda x, value: x+value, codes.values(), 0)
print(f"{round(fixedLines*100/allLines,2)} percent of calls from fixed lines in Bangalore are calls to other fixed lines in Bangalore.")
fixedLines, allLines
# Out:
# <class 'list'>
# The numbers called by people in Bangalore have codes:
# 022
# 040
# 04344
# 044
# 04546
# 0471
# 080
# 0821
# 7406
# 7795
# 7813
# 7829
# 8151
# 8152
# 8301
# 8431
# 8714
# 9008
# 9019
# 9035
# 9036
# 9241
# 9242
# 9341
# 9342
# 9343
# 9400
# 9448
# 9449
# 9526
# 9656
# 9738
# 9740
# 9741
# 9742
# 9844
# 9845
# 9900
# 9961
# 24.81 percent of calls from fixed lines in Bangalore are calls to other fixed lines in Bangalore.
# (268, 1080)

# %%
len(bangaloreExchanges)
# Out:
# 1080
